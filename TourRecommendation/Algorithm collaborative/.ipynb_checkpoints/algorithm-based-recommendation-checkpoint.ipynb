# %%
import numpy as np
import scipy.stats
import scipy.spatial
from sklearn.model_selection import KFold
import random
from sklearn.metrics import mean_squared_error
from math import sqrt
import math
import warnings
import sys
#from sklearn.utils.extmath import np.dot

warnings.simplefilter("error")

users = 4
items = 5
X=np.arange(0,6)
def readingFile(filename):
    f = open(filename,"r")
    data = []
    for row in f:
        r = row.split(',')
        e = [int(r[0]), int(r[1]), int(r[2])]
        data.append(e)
    return data

def similarity_user(data):
    print ("Hello User 1")
    #f_i_d = open("sim_user_based.txt","w")
    user_similarity_cosine = np.zeros((users,users))
    user_similarity_jaccard = np.zeros((users,users))
    user_similarity_pearson = np.zeros((users,users))
    for user1 in range(users):
        print (user1)
        for user2 in range(users):
            if np.count_nonzero(data[user1]) and np.count_nonzero(data[user2]):
                user_similarity_cosine[user1][user2] = 1-scipy.spatial.distance.cosine(data[user1],data[user2])
                user_similarity_jaccard[user1][user2] = 1-scipy.spatial.distance.jaccard(data[user1],data[user2])
                try:
                    if not math.isnan(scipy.stats.pearsonr(data[user1],data[user2])[0]):
                        user_similarity_pearson[user1][user2] = scipy.stats.pearsonr(data[user1],data[user2])[0]
                    else:
                        user_similarity_pearson[user1][user2] = 0
                except:
                    user_similarity_pearson[user1][user2] = 0

            #f_i_d.write(str(user1) + "," + str(user2) + "," + str(user_similarity_cosine[user1][user2]) + "," + str(user_similarity_jaccard[user1][user2]) + "," + str(user_similarity_pearson[user1][user2]) + "\n")
    #f_i_d.close()
    return user_similarity_cosine, user_similarity_jaccard, user_similarity_pearson

recommend_data = readingFile("test.csv")

similarity_user(recommend_data)

# %%
import pandas as pd

dict1 = {'age':10,
            'gender':1,
            'height':1,
            'weight':1,
            'ap_hi':1,
            'ap_lo':1,
            'cholesterol':1,
            'gluc':1,
            'smoke':1,
            'alco':1,
            'active':1}
           
dff=pd.DataFrame(dict1,index=[0])

finaldff=dff[['gender','cholesterol','smoke','alco','active']]

# %%
df1=pd.read_csv('ratings.csv',sep=',',error_bad_lines=False)

print(len(df1))
print(df1)
df=df1#.sample(n=1000,replace=True)
X = df.iloc[:,:-2].values # We drop our "target" feature and use all the remaining features in our dataframe to train the model.
y = df.iloc[:,2].values
# Out:
# 799999
#         2685  1422  2  973375612
# 0       1941  1929  4  974954081
# 1       3312    21  1  967955474
# 2       4553   161  5  964555191
# 3       2027   176  4  974675039
# 4       5289   982  4  961081792
# ...      ...   ... ..        ...
# 799994   857   905  4  975345551
# 799995  1501  3088  5  975351509
# 799996  1181  3098  3  974948916
# 799997  1294  3255  4  974874562
# 799998  4354  1235  4  965192935
#
# [799999 rows x 4 columns]

# %%
X
# Out:
# array([[1941, 1929],
#        [3312,   21],
#        [4553,  161],
#        ...,
#        [1181, 3098],
#        [1294, 3255],
#        [4354, 1235]], dtype=int64)

# %%
y
# Out:
# array([4, 1, 5, ..., 3, 4, 4], dtype=int64)

# %%
X1 = X # We drop our "target" feature and use all the remaining features in our dataframe to train the model.
y1 = y

# %%
import numpy as np
from scipy.spatial import distance
ycount=0
rowcount=0
countsofsys=0
y_actu=[]
y_pred=[]

for row in X1:
    outexpect=[]
    overall=[]
    print(row)
    rowcount+=1
    print('row count is ',rowcount)
    listofall=[]
    
    
    expected=y1[ycount]
    ycount+=1    

    countis=0
    for row1 in X1:
            y=row
            summation = 0
            print('check1')
            y_bar=row1
            print('check11',y_bar,'second is',y)
            #if y!=y_bar:
            print('check2')
            n = len(y) #finding total number of items in list
            for i in range (0,n):  #looping through each element of the list
                difference = y[i] - y_bar[i]  #finding the difference between observed and predicted value
                squared_difference = difference**2  #taking square of the differene 
                summation = summation + squared_difference  #taking a sum of all the differences
            MSE = summation/n  #dividing summation by total values to obtain average
            print("The Mean Square Error is: " , MSE)
            dst = distance.euclidean(y, y_bar)
            print("dst is: " , dst)
            if dst<0.02:
                outexpect.append(1.0)
            else:
                outexpect.append(0.0)
            if MSE<=0.5:
                outexpect.append(1.0)
            else:
                outexpect.append(0.0)
            #if len(outexpect)>len(X1):
            if len(outexpect)>10:
                break
    #outexpect.append(valis)
    y_actu.append(expected)
    valmax=max(outexpect,key=outexpect.count)
    #outexpect
    overall.append(valmax)
    print('from the logic',valmax)
    
    valis=1.0
    if valmax==1.0 and valis==1.0:
        valis=1.0
    if valmax==1.0 and valis==0.0:
        valis=0.0

    y_pred.append(valis)    
overallcorrect=countsofsys/(len(X1))
print('overallcorrect ',overallcorrect)
# Out:
# [1941 1929]
# row count is  1
# check1
# check11 [1941 1929] second is [1941 1929]
# check2
# The Mean Square Error is:  0.0
# dst is:  0.0
# check1
# check11 [3312   21] second is [1941 1929]
# check2
# The Mean Square Error is:  2760052.5
# dst is:  2349.490370271817
# check1
# check11 [4553  161] second is [1941 1929]
# check2
# The Mean Square Error is:  4974184.0
# dst is:  3154.103359118087
# check1
# check11 [2027  176] second is [1941 1929]
# check2
# The Mean Square Error is:  1540202.5
# dst is:  1755.108258769242
# check1
# check11 [5289  982] second is [1941 1929]
# check2
# The Mean Square Error is:  6052956.5
# dst is:  3479.3552563657536
# check1
# check11 [5607  440] second is [1941 1929]
# check2
# The Mean Square Error is:  7828338.5
# dst is:  3956.851905239821
# from the logic 0.0
# [3312   21]
# row count is  2
# check1
# check11 [1941 1929] second is [3312   21]
# check2
# The Mean Square Error is:  2760052.5
# dst is:  2349.490370271817
# check1
# check11 [3312   21] second is [3312   21]
# check2
# The Mean Square Error is:  0.0
# dst is:  0.0
# check1
# check11 [4553  161] second is [3312   21]
# check2
# The Mean Square Error is:  779840.5
# dst is:  1248.8718909479867
# check1
# check11 [2027  176] second is [3312   21]
# check2
# The Mean Square Error is:  837625.0
# dst is:  1294.314490377049
# check1
# check11 [5289  982] second is [3312   21]
# check2
# The Mean Square Error is:  2416025.0
# dst is:  2198.1924392554897
# check1
# check11 [5607  440] second is [3312   21]
# check2
# The Mean Square Error is:  2721293.0
# dst is:  2332.935061247955
# from the logic 0.0
# [4553  161]
# row count is  3
# check1
# check11 [1941 1929] second is [4553  161]
# check2
# The Mean Square Error is:  4974184.0
# dst is:  3154.103359118087
# check1
# check11 [3312   21] second is [4553  161]
# check2
# The Mean Square Error is:  779840.5
# dst is:  1248.8718909479867
# check1
# check11 [4553  161] second is [4553  161]
# check2
# The Mean Square Error is:  0.0
# dst is:  0.0
# check1
# check11 [2027  176] second is [4553  161]
# check2
# The Mean Square Error is:  3190450.5
# dst is:  2526.0445364244865
# check1
# check11 [5289  982] second is [4553  161]
# check2
# The Mean Square Error is:  607868.5
# dst is:  1102.6046435599662
# check1
# check11 [5607  440] second is [4553  161]
# check2
# The Mean Square Error is:  594378.5
# dst is:  1090.3013344942765
# from the logic 0.0
# [2027  176]
# row count is  4
# check1
# check11 [1941 1929] second is [2027  176]
# check2
# The Mean Square Error is:  1540202.5
# dst is:  1755.108258769242
# check1
# check11 [3312   21] second is [2027  176]
# check2
# The Mean Square Error is:  837625.0
# dst is:  1294.314490377049
# check1
# check11 [4553  161] second is [2027  176]
# check2
# The Mean Square Error is:  3190450.5
# dst is:  2526.0445364244865
# check1
# check11 [2027  176] second is [2027  176]
# check2
# The Mean Square Error is:  0.0
# dst is:  0.0
# check1
# check11 [5289  982] second is [2027  176]
# check2
# The Mean Square Error is:  5645140.0
# dst is:  3360.1011889524993
# check1
# check11 [5607  440] second is [2027  176]
# check2
# The Mean Square Error is:  6443048.0
# dst is:  3589.7208805142495
# from the logic 0.0
# [5289  982]
# row count is  5
# check1
# check11 [1941 1929] second is [5289  982]
# check2
# The Mean Square Error is:  6052956.5
# dst is:  3479.3552563657536
# check1
# check11 [3312   21] second is [5289  982]
# check2
# The Mean Square Error is:  2416025.0
# dst is:  2198.1924392554897
# check1
# check11 [4553  161] second is [5289  982]
# check2
# The Mean Square Error is:  607868.5
# dst is:  1102.6046435599662
# check1
# check11 [2027  176] second is [5289  982]
# check2
# The Mean Square Error is:  5645140.0
# dst is:  3360.1011889524993
# check1
# check11 [5289  982] second is [5289  982]
# check2
# The Mean Square Error is:  0.0
# dst is:  0.0
# check1
# check11 [5607  440] second is [5289  982]
# check2
# The Mean Square Error is:  197444.0
# dst is:  628.4011457659828
# from the logic 0.0
# [5607  440]
# row count is  6
# check1
# check11 [1941 1929] second is [5607  440]
# check2
# The Mean Square Error is:  7828338.5
# dst is:  3956.851905239821
# check1
# check11 [3312   21] second is [5607  440]
# check2
# The Mean Square Error is:  2721293.0
# dst is:  2332.935061247955
# check1
# check11 [4553  161] second is [5607  440]
# check2
# The Mean Square Error is:  594378.5
# dst is:  1090.3013344942765
# check1
# check11 [2027  176] second is [5607  440]
# check2
# The Mean Square Error is:  6443048.0
# dst is:  3589.7208805142495
# check1
# check11 [5289  982] second is [5607  440]
# check2
# The Mean Square Error is:  197444.0
# dst is:  628.4011457659828
# check1
# check11 [5607  440] second is [5607  440]
# check2
# The Mean Square Error is:  0.0
# dst is:  0.0
# from the logic 0.0
# [5626 3599]
# row count is  7
# check1
# check11 [1941 1929] second is [5626 3599]
# check2
# The Mean Square Error is:  8184062.5
# dst is:  4045.753947041268
# check1
# check11 [3312   21] second is [5626 3599]
# check2
# The Mean Square Error is:  9078340.0
# dst is:  4261.065594425882
# check1
# check11 [4553  161] second is [5626 3599]
# check2
# The Mean Square Error is:  6485586.5
# dst is:  3601.5514712412482
# check1
# check11 [2027  176] second is [5626 3599]
# check2
# The Mean Square Error is:  12334865.0
# dst is:  4966.863195216876
# check1
# check11 [5289  982] second is [5626 3599]
# check2
# The Mean Square Error is:  3481129.0
# dst is:  2638.609103296659
# check1
# check11 [5607  440] second is [5626 3599]
# check2
# The Mean Square Error is:  4989821.0
# dst is:  3159.057137818181
# from the logic 0.0
# [5587 2324]
# row count is  8
# check1
# check11 [1941 1929] second is [5587 2324]
# check2
# The Mean Square Error is:  6724670.5
# dst is:  3667.334318002655
# check1
# check11 [3312   21] second is [5587 2324]
# check2
# The Mean Square Error is:  5239717.0
# dst is:  3237.195391075429
# check1
# check11 [4553  161] second is [5587 2324]
# check2
# The Mean Square Error is:  2873862.5
# dst is:  2397.441344433686
# check1
# check11 [2027  176] second is [5587 2324]
# check2
# The Mean Square Error is:  8643752.0
# dst is:  4157.824431117793
# check1
# check11 [5289  982] second is [5587 2324]
# check2
# The Mean Square Error is:  944884.0
# dst is:  1374.6883283130035
# check1
# check11 [5607  440] second is [5587 2324]
# check2
# The Mean Square Error is:  1774928.0
# dst is:  1884.1061541218955
# from the logic 0.0
# [3851 3798]
# row count is  9
# check1
# check11 [1941 1929] second is [3851 3798]
# check2
# The Mean Square Error is:  3570630.5
# dst is:  2672.3137914548884
# check1
# check11 [3312   21] second is [3851 3798]
# check2
# The Mean Square Error is:  7278125.0
# dst is:  3815.2653905069305
# check1
# check11 [4553  161] second is [3851 3798]
# check2
# The Mean Square Error is:  6860286.5
# dst is:  3704.129182412514
# check1
# check11 [2027  176] second is [3851 3798]
# check2
# The Mean Square Error is:  8222930.0
# dst is:  4055.3495533677487
# check1
# check11 [5289  982] second is [3851 3798]
# check2
# The Mean Square Error is:  4998850.0
# dst is:  3161.9139773244938
# check1
# check11 [5607  440] second is [3851 3798]
# check2
# The Mean Square Error is:  7179850.0
# dst is:  3789.419480606495
# from the logic 0.0
# [2507  279]
# row count is  10
# check1
# check11 [1941 1929] second is [2507  279]
# check2
# The Mean Square Error is:  1521428.0
# dst is:  1744.3783993159282
# check1
# check11 [3312   21] second is [2507  279]
# check2
# The Mean Square Error is:  357294.5
# dst is:  845.3336619347416
# check1
# check11 [4553  161] second is [2507  279]
# check2
# The Mean Square Error is:  2100020.0
# dst is:  2049.3999121694137
# check1
# check11 [2027  176] second is [2507  279]
# check2
# The Mean Square Error is:  120504.5
# dst is:  490.92667476925715
# check1
# check11 [5289  982] second is [2507  279]
# check2
# The Mean Square Error is:  4116866.5
# dst is:  2869.4482047947827
# check1
# check11 [5607  440] second is [2507  279]
# check2
# The Mean Square Error is:  4817960.5
# dst is:  3104.177991030798
# from the logic 0.0
# [ 667 2291]
# row count is  11
# check1
# check11 [1941 1929] second is [ 667 2291]
# check2
# The Mean Square Error is:  877060.0
# dst is:  1324.4319537069468
# check1
# check11 [3312   21] second is [ 667 2291]
# check2
# The Mean Square Error is:  6074462.5
# dst is:  3485.530806060965
# check1
# check11 [4553  161] second is [ 667 2291]
# check2
# The Mean Square Error is:  9818948.0
# dst is:  4431.466574397239
# check1
# check11 [2027  176] second is [ 667 2291]
# check2
# The Mean Square Error is:  3161412.5
# dst is:  2514.5228175540583
# check1
# check11 [5289  982] second is [ 667 2291]
# check2
# The Mean Square Error is:  11538182.5
# dst is:  4803.786527313636
# check1
# check11 [5607  440] second is [ 667 2291]
# check2
# The Mean Square Error is:  13914900.5
# dst is:  5275.39581453373
# from the logic 0.0
# [5474 1097]
# row count is  12
# check1
# check11 [1941 1929] second is [5474 1097]
# check2
# The Mean Square Error is:  6587156.5
# dst is:  3629.643646420403
# check1
# check11 [3312   21] second is [5474 1097]
# check2
# The Mean Square Error is:  2916010.0
# dst is:  2414.957556562848
# check1
# check11 [4553  161] second is [5474 1097]
# check2
# The Mean Square Error is:  862168.5
# dst is:  1313.1401296129823
# check1
# check11 [2027  176] second is [5474 1097]
# check2
# The Mean Square Error is:  6365025.0
# dst is:  3567.9195618735575
# check1
# check11 [5289  982] second is [5474 1097]
# check2
# The Mean Square Error is:  23725.0
# dst is:  217.83020910791964
# check1
# check11 [5607  440] second is [5474 1097]
# check2
# The Mean Square Error is:  224669.0
# dst is:  670.3267859783018
# from the logic 0.0
# [4897 1291]
# row count is  13
# check1
# check11 [1941 1929] second is [4897 1291]
# check2
# The Mean Square Error is:  4572490.0
# dst is:  3024.0667982040345
# check1
# check11 [3312   21] second is [4897 1291]
# check2
# The Mean Square Error is:  2062562.5
# dst is:  2031.0403737986107
# check1
# check11 [4553  161] second is [4897 1291]
# check2
# The Mean Square Error is:  697618.0
# dst is:  1181.201083643255
# check1
# check11 [2027  176] second is [4897 1291]
# check2
# The Mean Square Error is:  4740062.5
# dst is:  3078.981162657544
# check1
# check11 [5289  982] second is [4897 1291]
# check2
# The Mean Square Error is:  124572.5
# dst is:  499.14426772226886
# check1
# check11 [5607  440] second is [4897 1291]
# check2
# The Mean Square Error is:  614150.5
# dst is:  1108.2874175952734
# from the logic 0.0
# [5310 3035]
# row count is  14
# check1
# check11 [1941 1929] second is [5310 3035]
# check2
# The Mean Square Error is:  6286698.5
# dst is:  3545.8986167119892
# check1
# check11 [3312   21] second is [5310 3035]
# check2
# The Mean Square Error is:  6538100.0
# dst is:  3616.102874642811
# check1
# check11 [4553  161] second is [5310 3035]
# check2
# The Mean Square Error is:  4416462.5
# dst is:  2972.023721305064
# check1
# check11 [2027  176] second is [5310 3035]
# check2
# The Mean Square Error is:  9475985.0
# dst is:  4353.386038476257
# check1
# check11 [5289  982] second is [5310 3035]
# check2
# The Mean Square Error is:  2107625.0
# dst is:  2053.1074009900212
# check1
# check11 [5607  440] second is [5310 3035]
# check2
# The Mean Square Error is:  3411117.0
# dst is:  2611.940657825135
# from the logic 0.0
# [3425 1422]
# row count is  15
# check1
# check11 [1941 1929] second is [3425 1422]
# check2
# The Mean Square Error is:  1229652.5
# dst is:  1568.2171405771587
# check1
# check11 [3312   21] second is [3425 1422]
# check2
# The Mean Square Error is:  987785.0
# dst is:  1405.5497145245342
# check1
# check11 [4553  161] second is [3425 1422]
# check2
# The Mean Square Error is:  1431252.5
# dst is:  1691.8939092035291
# check1
# check11 [2027  176] second is [3425 1422]
# check2
# The Mean Square Error is:  1753460.0
# dst is:  1872.6772279279737
# check1
# check11 [5289  982] second is [3425 1422]
# check2
# The Mean Square Error is:  1834048.0
# dst is:  1915.2274016419042
# check1
# check11 [5607  440] second is [3425 1422]
# check2
# The Mean Square Error is:  2862724.0
# dst is:  2392.7908391666833
# from the logic 0.0
# [2304  586]
# row count is  16
# check1
# check11 [1941 1929] second is [2304  586]
# check2
# The Mean Square Error is:  967709.0
# dst is:  1391.1930132084476
# check1
# check11 [3312   21] second is [2304  586]
# check2
# The Mean Square Error is:  667644.5
# dst is:  1155.5470565926773
# check1
# check11 [4553  161] second is [2304  586]
# check2
# The Mean Square Error is:  2619313.0
# dst is:  2288.8044914321536
# check1
# check11 [2027  176] second is [2304  586]
# check2
# The Mean Square Error is:  122414.5
# dst is:  494.80198059425754
# check1
# check11 [5289  982] second is [2304  586]
# check2
# The Mean Square Error is:  4533520.5
# dst is:  3011.1527692895293
# check1
# check11 [5607  440] second is [2304  586]
# check2
# The Mean Square Error is:  5465562.5
# dst is:  3306.225188942822
# from the logic 0.0
# [2529 3375]
# row count is  17
# check1
# check11 [1941 1929] second is [2529 3375]
# check2
# The Mean Square Error is:  1218330.0
# dst is:  1560.98046112051
# check1
# check11 [3312   21] second is [2529 3375]
# check2
# The Mean Square Error is:  5931202.5
# dst is:  3444.184228522046
# check1
# check11 [4553  161] second is [2529 3375]
# check2
# The Mean Square Error is:  7213186.0
# dst is:  3798.206418824548
# check1
# check11 [2027  176] second is [2529 3375]
# check2
# The Mean Square Error is:  5242802.5
# dst is:  3238.148390670199
# check1
# check11 [5289  982] second is [2529 3375]
# check2
# The Mean Square Error is:  6672024.5
# dst is:  3652.950725098821
# check1
# check11 [5607  440] second is [2529 3375]
# check2
# The Mean Square Error is:  9044154.5
# dst is:  4253.035269075487
# from the logic 0.0
# [4790 3267]
# row count is  18
# check1
# check11 [1941 1929] second is [4790 3267]
# check2
# The Mean Square Error is:  4953522.5
# dst is:  3147.5458694036533
# check1
# check11 [3312   21] second is [4790 3267]
# check2
# The Mean Square Error is:  6360500.0
# dst is:  3566.6510903086664
# check1
# check11 [4553  161] second is [4790 3267]
# check2
# The Mean Square Error is:  4851702.5
# dst is:  3115.0288923218673
# check1
# check11 [2027  176] second is [4790 3267]
# check2
# The Mean Square Error is:  8594225.0
# dst is:  4145.895560672025
# check1
# check11 [5289  982] second is [4790 3267]
# check2
# The Mean Square Error is:  2735113.0
# dst is:  2338.8514275173616
# check1
# check11 [5607  440] second is [4790 3267]
# check2
# The Mean Square Error is:  4329709.0
# dst is:  2942.68890642555
# from the logic 0.0
# [3441 3618]
# row count is  19
# check1
# check11 [1941 1929] second is [3441 3618]
# check2
# The Mean Square Error is:  2551360.5
# dst is:  2258.920317319759
# check1
# check11 [3312   21] second is [3441 3618]
# check2
# The Mean Square Error is:  6477525.0
# dst is:  3599.312434340759
# check1
# check11 [4553  161] second is [3441 3618]
# check2
# The Mean Square Error is:  6593696.5
# dst is:  3631.4450291860403
# check1
# check11 [2027  176] second is [3441 3618]
# check2
# The Mean Square Error is:  6923380.0
# dst is:  3721.1234862605675
# check1
# check11 [5289  982] second is [3441 3618]
# check2
# The Mean Square Error is:  5181800.0
# dst is:  3219.2545721020574
# check1
# check11 [5607  440] second is [3441 3618]
# check2
# The Mean Square Error is:  7395620.0
# dst is:  3845.9381170268457
# from the logic 0.0
# [ 446 1136]
# row count is  20
# check1
# check11 [1941 1929] second is [ 446 1136]
# check2
# The Mean Square Error is:  1431937.0
# dst is:  1692.2984370376284
# check1
# check11 [3312   21] second is [ 446 1136]
# check2
# The Mean Square Error is:  4728590.5
# dst is:  3075.252997722301
# check1
# check11 [4553  161] second is [ 446 1136]
# check2
# The Mean Square Error is:  8909037.0
# dst is:  4221.146052910276
# check1
# check11 [2027  176] second is [ 446 1136]
# check2
# The Mean Square Error is:  1710580.5
# dst is:  1849.638072705036
# check1
# check11 [5289  982] second is [ 446 1136]
# check2
# The Mean Square Error is:  11739182.5
# dst is:  4845.447863717037
# check1
# check11 [5607  440] second is [ 446 1136]
# check2
# The Mean Square Error is:  13560168.5
# dst is:  5207.718982433672
# from the logic 0.0
# [3452 1222]
# row count is  21
# check1
# check11 [1941 1929] second is [3452 1222]
# check2
# The Mean Square Error is:  1391485.0
# dst is:  1668.2236061151993
# check1
# check11 [3312   21] second is [3452 1222]
# check2
# The Mean Square Error is:  731000.5
# dst is:  1209.132333535085
# check1
# check11 [4553  161] second is [3452 1222]
# check2
# The Mean Square Error is:  1168961.0
# dst is:  1529.0264876711587
# check1
# check11 [2027  176] second is [3452 1222]
# check2
# The Mean Square Error is:  1562370.5
# dst is:  1767.6936951859052
# check1
# check11 [5289  982] second is [3452 1222]
# check2
# The Mean Square Error is:  1716084.5
# dst is:  1852.6114001592455
# check1
# check11 [5607  440] second is [3452 1222]
# check2
# The Mean Square Error is:  2627774.5
# dst is:  2292.4984187562704
# from the logic 0.0
# [1176  480]
# row count is  22
# check1
# check11 [1941 1929] second is [1176  480]
# check2
# The Mean Square Error is:  1342413.0
# dst is:  1638.543865753981
# check1
# check11 [3312   21] second is [1176  480]
# check2
# The Mean Square Error is:  2386588.5
# dst is:  2184.7601699042393
# check1
# check11 [4553  161] second is [1176  480]
# check2
# The Mean Square Error is:  5752945.0
# dst is:  3392.033313515656
# check1
# check11 [2027  176] second is [1176  480]
# check2
# The Mean Square Error is:  408308.5
# dst is:  903.6686339582668
# check1
# check11 [5289  982] second is [1176  480]
# check2
# The Mean Square Error is:  8584386.5
# dst is:  4143.521811213258
# check1
# check11 [5607  440] second is [1176  480]
# check2
# The Mean Square Error is:  9817680.5
# dst is:  4431.1805424739805
# from the logic 0.0
# [2911   47]
# row count is  23
# check1
# check11 [1941 1929] second is [2911   47]
# check2
# The Mean Square Error is:  2241412.0
# dst is:  2117.268051050693
# check1
# check11 [3312   21] second is [2911   47]
# check2
# The Mean Square Error is:  80738.5
# dst is:  401.84200875468457
# check1
# check11 [4553  161] second is [2911   47]
# check2
# The Mean Square Error is:  1354580.0
# dst is:  1645.9526117115279
# check1
# check11 [2027  176] second is [2911   47]
# check2
# The Mean Square Error is:  399048.5
# dst is:  893.3627482719436
# check1
# check11 [5289  982] second is [2911   47]
# check2
# The Mean Square Error is:  3264554.5
# dst is:  2555.2121242667895
# check1
# check11 [5607  440] second is [2911   47]
# check2
# The Mean Square Error is:  3711432.5
# dst is:  2724.493530915425
# from the logic 0.0
# [4258  468]
# row count is  24
# check1
# check11 [1941 1929] second is [4258  468]
# check2
# The Mean Square Error is:  3751505.0
# dst is:  2739.162280698243
# check1
# check11 [3312   21] second is [4258  468]
# check2
# The Mean Square Error is:  547362.5
# dst is:  1046.29106848907
# check1
# check11 [4553  161] second is [4258  468]
# check2
# The Mean Square Error is:  90637.0
# dst is:  425.76284478568584
# check1
# check11 [2027  176] second is [4258  468]
# check2
# The Mean Square Error is:  2531312.5
# dst is:  2250.027777606312
# check1
# check11 [5289  982] second is [4258  468]
# check2
# The Mean Square Error is:  663578.5
# dst is:  1152.0230032425568
# check1
# check11 [5607  440] second is [4258  468]
# check2
# The Mean Square Error is:  910292.5
# dst is:  1349.290554328459
# from the logic 0.0
# [ 252 2912]
# row count is  25
# check1
# check11 [1941 1929] second is [ 252 2912]
# check2
# The Mean Square Error is:  1909505.0
# dst is:  1954.2287481254593
# check1
# check11 [3312   21] second is [ 252 2912]
# check2
# The Mean Square Error is:  8860740.5
# dst is:  4209.688943378121
# check1
# check11 [4553  161] second is [ 252 2912]
# check2
# The Mean Square Error is:  13033301.0
# dst is:  5105.546199967247
# check1
# check11 [2027  176] second is [ 252 2912]
# check2
# The Mean Square Error is:  5318160.5
# dst is:  3261.3373023960585
# check1
# check11 [5289  982] second is [ 252 2912]
# check2
# The Mean Square Error is:  14548134.5
# dst is:  5394.09575369218
# check1
# check11 [5607  440] second is [ 252 2912]
# check2
# The Mean Square Error is:  17393404.5
# dst is:  5898.034333572499
# from the logic 0.0
# [2338 1356]
# row count is  26
# check1
# check11 [1941 1929] second is [2338 1356]
# check2
# The Mean Square Error is:  242969.0
# dst is:  697.092533312472
# check1
# check11 [3312   21] second is [2338 1356]
# check2
# The Mean Square Error is:  1365450.5
# dst is:  1652.5437966964748
# check1
# check11 [4553  161] second is [2338 1356]
# check2
# The Mean Square Error is:  3167125.0
# dst is:  2516.7935950331726
# check1
# check11 [2027  176] second is [2338 1356]
# check2
# The Mean Square Error is:  744560.5
# dst is:  1220.295456026941
# check1
# check11 [5289  982] second is [2338 1356]
# check2
# The Mean Square Error is:  4424138.5
# dst is:  2974.6053519752836
# check1
# check11 [5607  440] second is [2338 1356]
# check2
# The Mean Square Error is:  5762708.5
# dst is:  3394.9104553728657
# from the logic 0.0
# [1697 3548]
# row count is  27
# check1
# check11 [1941 1929] second is [1697 3548]
# check2
# The Mean Square Error is:  1340348.5
# dst is:  1637.283420791892
# check1
# check11 [3312   21] second is [1697 3548]
# check2
# The Mean Square Error is:  7523977.0
# dst is:  3879.1692409586876
# check1
# check11 [4553  161] second is [1697 3548]
# check2
# The Mean Square Error is:  9814252.5
# dst is:  4430.406866191863
# check1
# check11 [2027  176] second is [1697 3548]
# check2
# The Mean Square Error is:  5739642.0
# dst is:  3388.109207212778
# check1
# check11 [5289  982] second is [1697 3548]
# check2
# The Mean Square Error is:  9743410.0
# dst is:  4414.387839780279
# check1
# check11 [5607  440] second is [1697 3548]
# check2
# The Mean Square Error is:  12473882.0
# dst is:  4994.773668545953
# from the logic 0.0
# [4448 3566]
# row count is  28
# check1
# check11 [1941 1929] second is [4448 3566]
# check2
# The Mean Square Error is:  4482409.0
# dst is:  2994.1305916743177
# check1
# check11 [3312   21] second is [4448 3566]
# check2
# The Mean Square Error is:  6928760.5
# dst is:  3722.5691397205774
# check1
# check11 [4553  161] second is [4448 3566]
# check2
# The Mean Square Error is:  5802525.0
# dst is:  3406.6185580425645
# check1
# check11 [2027  176] second is [4448 3566]
# check2
# The Mean Square Error is:  8676670.5
# dst is:  4165.734148982626
# check1
# check11 [5289  982] second is [4448 3566]
# check2
# The Mean Square Error is:  3692168.5
# dst is:  2717.413660081954
# check1
# check11 [5607  440] second is [4448 3566]
# check2
# The Mean Square Error is:  5557578.5
# dst is:  3333.9401614306157
# from the logic 0.0
# [2788  296]
# row count is  29
# check1
# check11 [1941 1929] second is [2788  296]
# check2
# The Mean Square Error is:  1692049.0
# dst is:  1839.5918025475107
# check1
# check11 [3312   21] second is [2788  296]
# check2
# The Mean Square Error is:  175100.5
# dst is:  591.777829932822
# check1
# check11 [4553  161] second is [2788  296]
# check2
# The Mean Square Error is:  1566725.0
# dst is:  1770.1553604133169
# check1
# check11 [2027  176] second is [2788  296]
# check2
# The Mean Square Error is:  296760.5
# dst is:  770.4031412189335
# check1
# check11 [5289  982] second is [2788  296]
# check2
# The Mean Square Error is:  3362798.5
# dst is:  2593.3755994841936
# check1
# check11 [5607  440] second is [2788  296]
# check2
# The Mean Square Error is:  3983748.5
# dst is:  2822.6755038438264
# from the logic 0.0
# [3393 3551]
# row count is  30
# check1
# check11 [1941 1929] second is [3393 3551]
# check2
# The Mean Square Error is:  2369594.0
# dst is:  2176.967615744433
# check1
# check11 [3312   21] second is [3393 3551]
# check2
# The Mean Square Error is:  6233730.5
# dst is:  3530.929197817481
# check1
# check11 [4553  161] second is [3393 3551]
# check2
# The Mean Square Error is:  6418850.0
# dst is:  3582.973625356458
# check1
# check11 [2027  176] second is [3393 3551]
# check2
# The Mean Square Error is:  6628290.5
# dst is:  3640.9588022937037
# check1
# check11 [5289  982] second is [3393 3551]
# check2
# The Mean Square Error is:  5097288.5
# dst is:  3192.8947680748893
# check1
# check11 [5607  440] second is [3393 3551]
# check2
# The Mean Square Error is:  7290058.5
# dst is:  3818.3919390235465
# from the logic 0.0
# [1870 2424]
# row count is  31
# check1
# check11 [1941 1929] second is [1870 2424]
# check2
# The Mean Square Error is:  125033.0
# dst is:  500.0659956445749
# check1
# check11 [3312   21] second is [1870 2424]
# check2
# The Mean Square Error is:  3926886.5
# dst is:  2802.4583850612303
# check1
# check11 [4553  161] second is [1870 2424]
# check2
# The Mean Square Error is:  6159829.0
# dst is:  3509.9370364723068
# check1
# check11 [2027  176] second is [1870 2424]
# check2
# The Mean Square Error is:  2539076.5
# dst is:  2253.475759798627
# check1
# check11 [5289  982] second is [1870 2424]
# check2
# The Mean Square Error is:  6884462.5
# dst is:  3710.6502125638303
# check1
# check11 [5607  440] second is [1870 2424]
# check2
# The Mean Square Error is:  8950712.5
# dst is:  4231.007563217065
# from the logic 0.0
# [2143 3527]
# row count is  32
# check1
# check11 [1941 1929] second is [2143 3527]
# check2
# The Mean Square Error is:  1297204.0
# dst is:  1610.7166107046887
# check1
# check11 [3312   21] second is [2143 3527]
# check2
# The Mean Square Error is:  6829298.5
# dst is:  3695.753914967824
# check1
# check11 [4553  161] second is [2143 3527]
# check2
# The Mean Square Error is:  8569028.0
# dst is:  4139.813522370301
# check1
# check11 [2027  176] second is [2143 3527]
# check2
# The Mean Square Error is:  5621328.5
# dst is:  3353.007157761522
# check1
# check11 [5289  982] second is [2143 3527]
# check2
# The Mean Square Error is:  8187170.5
# dst is:  4046.5220869284776
# check1
# check11 [5607  440] second is [2143 3527]
# check2
# The Mean Square Error is:  10764432.5
# dst is:  4639.920796737806
# from the logic 0.0
# [ 415 3538]
# row count is  33
# check1
# check11 [1941 1929] second is [ 415 3538]
# check2
# The Mean Square Error is:  2458778.5
# dst is:  2217.5565381743936
# check1
# check11 [3312   21] second is [ 415 3538]
# check2
# The Mean Square Error is:  10380949.0
# dst is:  4556.522577580407
# check1
# check11 [4553  161] second is [ 415 3538]
# check2
# The Mean Square Error is:  14263586.5
# dst is:  5341.08350430884
# check1
# check11 [2027  176] second is [ 415 3538]
# check2
# The Mean Square Error is:  6950794.0
# dst is:  3728.4833377661753
# check1
# check11 [5289  982] second is [ 415 3538]
# check2
# The Mean Square Error is:  15144506.0
# dst is:  5503.545402738129
# check1
# check11 [5607  440] second is [ 415 3538]
# check2
# The Mean Square Error is:  18277234.0
# dst is:  6046.029110085396
# from the logic 0.0
# [2840 2567]
# row count is  34
# check1
# check11 [1941 1929] second is [2840 2567]
# check2
# The Mean Square Error is:  607622.5
# dst is:  1102.3815129073964
# check1
# check11 [3312   21] second is [2840 2567]
# check2
# The Mean Square Error is:  3352450.0
# dst is:  2589.382165691268
# check1
# check11 [4553  161] second is [2840 2567]
# check2
# The Mean Square Error is:  4361602.5
# dst is:  2953.5072371673646
# check1
# check11 [2027  176] second is [2840 2567]
# check2
# The Mean Square Error is:  3188925.0
# dst is:  2525.4405556258894
# check1
# check11 [5289  982] second is [2840 2567]
# check2
# The Mean Square Error is:  4254913.0
# dst is:  2917.160605794614
# check1
# check11 [5607  440] second is [2840 2567]
# check2
# The Mean Square Error is:  6090209.0
# dst is:  3490.045558441895
# from the logic 0.0
# [2887 3591]
# row count is  35
# check1
# check11 [1941 1929] second is [2887 3591]
# check2
# The Mean Square Error is:  1828580.0
# dst is:  1912.3702570370624
# check1
# check11 [3312   21] second is [2887 3591]
# check2
# The Mean Square Error is:  6462762.5
# dst is:  3595.208617034622
# check1
# check11 [4553  161] second is [2887 3591]
# check2
# The Mean Square Error is:  7270228.0
# dst is:  3813.194985835369
# check1
# check11 [2027  176] second is [2887 3591]
# check2
# The Mean Square Error is:  6200912.5
# dst is:  3521.6224953847623
# check1
# check11 [5289  982] second is [2887 3591]
# check2
# The Mean Square Error is:  6288242.5
# dst is:  3546.3340226211067
# check1
# check11 [5607  440] second is [2887 3591]
# check2
# The Mean Square Error is:  8663600.5
# dst is:  4162.595464370757
# from the logic 0.0
# [1470 1617]
# row count is  36
# check1
# check11 [1941 1929] second is [1470 1617]
# check2
# The Mean Square Error is:  159592.5
# dst is:  564.9646006609618
# check1
# check11 [3312   21] second is [1470 1617]
# check2
# The Mean Square Error is:  2970090.0
# dst is:  2437.2484485583327
# check1
# check11 [4553  161] second is [1470 1617]
# check2
# The Mean Square Error is:  5812412.5
# dst is:  3409.5197609047523
# check1
# check11 [2027  176] second is [1470 1617]
# check2
# The Mean Square Error is:  1193365.0
# dst is:  1544.9045277945172
# check1
# check11 [5289  982] second is [1470 1617]
# check2
# The Mean Square Error is:  7493993.0
# dst is:  3871.432034790227
# check1
# check11 [5607  440] second is [1470 1617]
# check2
# The Mean Square Error is:  9250049.0
# dst is:  4301.174025774823
# from the logic 0.0
# [2351 1267]
# row count is  37
# check1
# check11 [1941 1929] second is [2351 1267]
# check2
# The Mean Square Error is:  303172.0
# dst is:  778.6809359423152
# check1
# check11 [3312   21] second is [2351 1267]
# check2
# The Mean Square Error is:  1238018.5
# dst is:  1573.5428179747762
# check1
# check11 [4553  161] second is [2351 1267]
# check2
# The Mean Square Error is:  3036020.0
# dst is:  2464.150969401023
# check1
# check11 [2027  176] second is [2351 1267]
# check2
# The Mean Square Error is:  647628.5
# dst is:  1138.0935813895094
# check1
# check11 [5289  982] second is [2351 1267]
# check2
# The Mean Square Error is:  4356534.5
# dst is:  2951.7908123713646
# check1
# check11 [5607  440] second is [2351 1267]
# check2
# The Mean Square Error is:  5642732.5
# dst is:  3359.3846162653062
# from the logic 0.0
# [ 466 1136]
# row count is  38
# check1
# check11 [1941 1929] second is [ 466 1136]
# check2
# The Mean Square Error is:  1402237.0
# dst is:  1674.656382664814
# check1
# check11 [3312   21] second is [ 466 1136]
# check2
# The Mean Square Error is:  4671470.5
# dst is:  3056.6224824142087
# check1
# check11 [4553  161] second is [ 466 1136]
# check2
# The Mean Square Error is:  8827097.0
# dst is:  4201.689422125343
# check1
# check11 [2027  176] second is [ 466 1136]
# check2
# The Mean Square Error is:  1679160.5
# dst is:  1832.5722359568804
# check1
# check11 [5289  982] second is [ 466 1136]
# check2
# The Mean Square Error is:  11642522.5
# dst is:  4825.4580093499935
# check1
# check11 [5607  440] second is [ 466 1136]
# check2
# The Mean Square Error is:  13457148.5
# dst is:  5187.8990930819
# from the logic 0.0
# [ 749 2553]
# row count is  39
# check1
# check11 [1941 1929] second is [ 749 2553]
# check2
# The Mean Square Error is:  905120.0
# dst is:  1345.4515970483665
# check1
# check11 [3312   21] second is [ 749 2553]
# check2
# The Mean Square Error is:  6489996.5
# dst is:  3602.7757354573155
# check1
# check11 [4553  161] second is [ 749 2553]
# check2
# The Mean Square Error is:  10096040.0
# dst is:  4493.559836032007
# check1
# check11 [2027  176] second is [ 749 2553]
# check2
# The Mean Square Error is:  3641706.5
# dst is:  2698.779909514668
# check1
# check11 [5289  982] second is [ 749 2553]
# check2
# The Mean Square Error is:  11539820.5
# dst is:  4804.1274962265525
# check1
# check11 [5607  440] second is [ 749 2553]
# check2
# The Mean Square Error is:  14032466.5
# dst is:  5297.6346608651675
# from the logic 0.0
# [1483 2622]
# row count is  40
# check1
# check11 [1941 1929] second is [1483 2622]
# check2
# The Mean Square Error is:  345006.5
# dst is:  830.6702113354012
# check1
# check11 [3312   21] second is [1483 2622]
# check2
# The Mean Square Error is:  5055221.0
# dst is:  3179.692123461012
# check1
# check11 [4553  161] second is [1483 2622]
# check2
# The Mean Square Error is:  7740710.5
# dst is:  3934.643694160883
# check1
# check11 [2027  176] second is [1483 2622]
# check2
# The Mean Square Error is:  3139426.0
# dst is:  2505.7637558237607
# check1
# check11 [5289  982] second is [1483 2622]
# check2
# The Mean Square Error is:  8587618.0
# dst is:  4144.301629949248
# check1
# check11 [5607  440] second is [1483 2622]
# check2
# The Mean Square Error is:  10884250.0
# dst is:  4665.672513153918
# from the logic 0.0
# [1694 1259]
# row count is  41
# check1
# check11 [1941 1929] second is [1694 1259]
# check2
# The Mean Square Error is:  254954.5
# dst is:  714.07912726812
# check1
# check11 [3312   21] second is [1694 1259]
# check2
# The Mean Square Error is:  2075284.0
# dst is:  2037.2942840934886
# check1
# check11 [4553  161] second is [1694 1259]
# check2
# The Mean Square Error is:  4689742.5
# dst is:  3062.594488338278
# check1
# check11 [2027  176] second is [1694 1259]
# check2
# The Mean Square Error is:  641889.0
# dst is:  1133.0392755769767
# check1
# check11 [5289  982] second is [1694 1259]
# check2
# The Mean Square Error is:  6500377.0
# dst is:  3605.6558349348875
# check1
# check11 [5607  440] second is [1694 1259]
# check2
# The Mean Square Error is:  7991165.0
# dst is:  3997.790639840961
# from the logic 0.0
# [5916  615]
# row count is  42
# check1
# check11 [1941 1929] second is [5916  615]
# check2
# The Mean Square Error is:  8763610.5
# dst is:  4186.552400245338
# check1
# check11 [3312   21] second is [5916  615]
# check2
# The Mean Square Error is:  3566826.0
# dst is:  2670.889739393972
# check1
# check11 [4553  161] second is [5916  615]
# check2
# The Mean Square Error is:  1031942.5
# dst is:  1436.6227758183427
# check1
# check11 [2027  176] second is [5916  615]
# check2
# The Mean Square Error is:  7658521.0
# dst is:  3913.69927306634
# check1
# check11 [5289  982] second is [5916  615]
# check2
# The Mean Square Error is:  263909.0
# dst is:  726.5108395612552
# check1
# check11 [5607  440] second is [5916  615]
# check2
# The Mean Square Error is:  63053.0
# dst is:  355.1140661815581
# from the logic 0.0
# [5492 1059]
# row count is  43
# check1
# check11 [1941 1929] second is [5492 1059]
# check2
# The Mean Square Error is:  6683250.5
# dst is:  3656.0225655758745
# check1
# check11 [3312   21] second is [5492 1059]
# check2
# The Mean Square Error is:  2914922.0
# dst is:  2414.506989014528
# check1
# check11 [4553  161] second is [5492 1059]
# check2
# The Mean Square Error is:  844062.5
# dst is:  1299.2786460186283
# check1
# check11 [2027  176] second is [5492 1059]
# check2
# The Mean Square Error is:  6392957.0
# dst is:  3575.7396437660277
# check1
# check11 [5289  982] second is [5492 1059]
# check2
# The Mean Square Error is:  23569.0
# dst is:  217.1128738697915
# check1
# check11 [5607  440] second is [5492 1059]
# check2
# The Mean Square Error is:  198193.0
# dst is:  629.5919313333042
# from the logic 0.0
# [ 412 3394]
# row count is  44
# check1
# check11 [1941 1929] second is [ 412 3394]
# check2
# The Mean Square Error is:  2242033.0
# dst is:  2117.5613332321686
# check1
# check11 [3312   21] second is [ 412 3394]
# check2
# The Mean Square Error is:  9893564.5
# dst is:  4448.272586072037
# check1
# check11 [4553  161] second is [ 412 3394]
# check2
# The Mean Square Error is:  13800085.0
# dst is:  5253.586394074052
# check1
# check11 [2027  176] second is [ 412 3394]
# check2
# The Mean Square Error is:  6481874.5
# dst is:  3600.5206567939586
# check1
# check11 [5289  982] second is [ 412 3394]
# check2
# The Mean Square Error is:  14801436.5
# dst is:  5440.852231038811
# check1
# check11 [5607  440] second is [ 412 3394]
# check2
# The Mean Square Error is:  17857070.5
# dst is:  5976.130938993891
# from the logic 0.0
# [2931  595]
# row count is  45
# check1
# check11 [1941 1929] second is [2931  595]
# check2
# The Mean Square Error is:  1379828.0
# dst is:  1661.2212375237682
# check1
# check11 [3312   21] second is [2931  595]
# check2
# The Mean Square Error is:  237318.5
# dst is:  688.9390393931817
# check1
# check11 [4553  161] second is [2931  595]
# check2
# The Mean Square Error is:  1409620.0
# dst is:  1679.0592604193575
# check1
# check11 [2027  176] second is [2931  595]
# check2
# The Mean Square Error is:  496388.5
# dst is:  996.3819548747358
# check1
# check11 [5289  982] second is [2931  595]
# check2
# The Mean Square Error is:  2854966.5
# dst is:  2389.5466097149056
# check1
# check11 [5607  440] second is [2931  595]
# check2
# The Mean Square Error is:  3592500.5
# dst is:  2680.4852172694405
# from the logic 0.0
# [1426 2427]
# row count is  46
# check1
# check11 [1941 1929] second is [1426 2427]
# check2
# The Mean Square Error is:  256614.5
# dst is:  716.400027917364
# check1
# check11 [3312   21] second is [1426 2427]
# check2
# The Mean Square Error is:  4672916.0
# dst is:  3057.095353436003
# check1
# check11 [4553  161] second is [1426 2427]
# check2
# The Mean Square Error is:  7456442.5
# dst is:  3861.7204714997174
# check1
# check11 [2027  176] second is [1426 2427]
# check2
# The Mean Square Error is:  2714101.0
# dst is:  2329.850209777444
# check1
# check11 [5289  982] second is [1426 2427]
# check2
# The Mean Square Error is:  8505397.0
# dst is:  4124.4143826730115
# check1
# check11 [5607  440] second is [1426 2427]
# check2
# The Mean Square Error is:  10714465.0
# dst is:  4629.139228841578
# from the logic 0.0
# [1448 3394]
# row count is  47
# check1
# check11 [1941 1929] second is [1448 3394]
# check2
# The Mean Square Error is:  1194637.0
# dst is:  1545.7276603593532
# check1
# check11 [3312   21] second is [1448 3394]
# check2
# The Mean Square Error is:  7425812.5
# dst is:  3853.7806112958738
# check1
# check11 [4553  161] second is [1448 3394]
# check2
# The Mean Square Error is:  10046657.0
# dst is:  4482.556636563559
# check1
# check11 [2027  176] second is [1448 3394]
# check2
# The Mean Square Error is:  5345382.5
# dst is:  3269.6735311036787
# check1
# check11 [5289  982] second is [1448 3394]
# check2
# The Mean Square Error is:  10285512.5
# dst is:  4535.529186324347
# check1
# check11 [5607  440] second is [1448 3394]
# check2
# The Mean Square Error is:  13011698.5
# dst is:  5101.313262288447
# from the logic 0.0
# [5046 1101]
# row count is  48
# check1
# check11 [1941 1929] second is [5046 1101]
# check2
# The Mean Square Error is:  5163304.5
# dst is:  3213.504162125825
# check1
# check11 [3312   21] second is [5046 1101]
# check2
# The Mean Square Error is:  2086578.0
# dst is:  2042.830389435207
# check1
# check11 [4553  161] second is [5046 1101]
# check2
# The Mean Square Error is:  563324.5
# dst is:  1061.437233189038
# check1
# check11 [2027  176] second is [5046 1101]
# check2
# The Mean Square Error is:  4984993.0
# dst is:  3157.5284638463672
# check1
# check11 [5289  982] second is [5046 1101]
# check2
# The Mean Square Error is:  36605.0
# dst is:  270.57346507002495
# check1
# check11 [5607  440] second is [5046 1101]
# check2
# The Mean Square Error is:  375821.0
# dst is:  866.9728946166656
# from the logic 0.0
# [3625 1603]
# row count is  49
# check1
# check11 [1941 1929] second is [3625 1603]
# check2
# The Mean Square Error is:  1471066.0
# dst is:  1715.264411104014
# check1
# check11 [3312   21] second is [3625 1603]
# check2
# The Mean Square Error is:  1300346.5
# dst is:  1612.6664255201695
# check1
# check11 [4553  161] second is [3625 1603]
# check2
# The Mean Square Error is:  1470274.0
# dst is:  1714.8026125475783
# check1
# check11 [2027  176] second is [3625 1603]
# check2
# The Mean Square Error is:  2294966.5
# dst is:  2142.412892044855
# check1
# check11 [5289  982] second is [3625 1603]
# check2
# The Mean Square Error is:  1577268.5
# dst is:  1776.1016299750418
# check1
# check11 [5607  440] second is [3625 1603]
# check2
# The Mean Square Error is:  2640446.5
# dst is:  2298.019364583336
# from the logic 0.0
# [3410 2291]
# row count is  50
# check1
# check11 [1941 1929] second is [3410 2291]
# check2
# The Mean Square Error is:  1144502.5
# dst is:  1512.9458020695918
# check1
# check11 [3312   21] second is [3410 2291]
# check2
# The Mean Square Error is:  2581252.0
# dst is:  2272.1144337378782
# check1
# check11 [4553  161] second is [3410 2291]
# check2
# The Mean Square Error is:  2921674.5
# dst is:  2417.3020084383334
# check1
# check11 [2027  176] second is [3410 2291]
# check2
# The Mean Square Error is:  3192957.0
# dst is:  2527.0366044044554
# check1
# check11 [5289  982] second is [3410 2291]
# check2
# The Mean Square Error is:  2622061.0
# dst is:  2290.004803488412
# check1
# check11 [5607  440] second is [3410 2291]
# check2
# The Mean Square Error is:  4126505.0
# dst is:  2872.805249229401
# from the logic 0.0
# [  45 1580]
# row count is  51
# check1
# check11 [1941 1929] second is [  45 1580]
# check2
# The Mean Square Error is:  1858308.5
# dst is:  1927.8529508237914
# check1
# check11 [3312   21] second is [  45 1580]
# check2
# The Mean Square Error is:  6551885.0
# dst is:  3619.912982379549
# check1
# check11 [4553  161] second is [  45 1580]
# check2
# The Mean Square Error is:  11167812.5
# dst is:  4726.058082588491
# check1
# check11 [2027  176] second is [  45 1580]
# check2
# The Mean Square Error is:  2949770.0
# dst is:  2428.896868951006
# check1
# check11 [5289  982] second is [  45 1580]
# check2
# The Mean Square Error is:  13928570.0
# dst is:  5277.986358451488
# check1
# check11 [5607  440] second is [  45 1580]
# check2
# The Mean Square Error is:  16117722.0
# dst is:  5677.626616817982
# from the logic 0.0
# [2572   16]
# row count is  52
# check1
# check11 [1941 1929] second is [2572   16]
# check2
# The Mean Square Error is:  2028865.0
# dst is:  2014.3807981610628
# check1
# check11 [3312   21] second is [2572   16]
# check2
# The Mean Square Error is:  273812.5
# dst is:  740.0168916991017
# check1
# check11 [4553  161] second is [2572   16]
# check2
# The Mean Square Error is:  1972693.0
# dst is:  1986.299574585868
# check1
# check11 [2027  176] second is [2572   16]
# check2
# The Mean Square Error is:  161312.5
# dst is:  568.000880281008
# check1
# check11 [5289  982] second is [2572   16]
# check2
# The Mean Square Error is:  4157622.5
# dst is:  2883.6166527470327
# check1
# check11 [5607  440] second is [2572   16]
# check2
# The Mean Square Error is:  4695500.5
# dst is:  3064.474016858358
# from the logic 0.0
# [4979 2013]
# row count is  53
# check1
# check11 [1941 1929] second is [4979 2013]
# check2
# The Mean Square Error is:  4618250.0
# dst is:  3039.1610684529373
# check1
# check11 [3312   21] second is [4979 2013]
# check2
# The Mean Square Error is:  3373476.5
# dst is:  2597.4897497391594
# check1
# check11 [4553  161] second is [4979 2013]
# check2
# The Mean Square Error is:  1805690.0
# dst is:  1900.3631231951435
# check1
# check11 [2027  176] second is [4979 2013]
# check2
# The Mean Square Error is:  6044436.5
# dst is:  3476.9056645241326
# check1
# check11 [5289  982] second is [4979 2013]
# check2
# The Mean Square Error is:  579530.5
# dst is:  1076.596953367415
# check1
# check11 [5607  440] second is [4979 2013]
# check2
# The Mean Square Error is:  1434356.5
# dst is:  1693.727545976625
# from the logic 0.0
# [2221 2456]
# row count is  54
# check1
# check11 [1941 1929] second is [2221 2456]
# check2
# The Mean Square Error is:  178064.5
# dst is:  596.7654480614641
# check1
# check11 [3312   21] second is [2221 2456]
# check2
# The Mean Square Error is:  3559753.0
# dst is:  2668.240244055996
# check1
# check11 [4553  161] second is [2221 2456]
# check2
# The Mean Square Error is:  5352624.5
# dst is:  3271.8876814462933
# check1
# check11 [2027  176] second is [2221 2456]
# check2
# The Mean Square Error is:  2618018.0
# dst is:  2288.238623920154
# check1
# check11 [5289  982] second is [2221 2456]
# check2
# The Mean Square Error is:  5792650.0
# dst is:  3403.718554757429
# check1
# check11 [5607  440] second is [2221 2456]
# check2
# The Mean Square Error is:  7764626.0
# dst is:  3940.7171936082905
# from the logic 0.0
# [1051 1127]
# row count is  55
# check1
# check11 [1941 1929] second is [1051 1127]
# check2
# The Mean Square Error is:  717652.0
# dst is:  1198.0417355000618
# check1
# check11 [3312   21] second is [1051 1127]
# check2
# The Mean Square Error is:  3167678.5
# dst is:  2517.0135081083695
# check1
# check11 [4553  161] second is [1051 1127]
# check2
# The Mean Square Error is:  6598580.0
# dst is:  3632.7895617555387
# check1
# check11 [2027  176] second is [1051 1127]
# check2
# The Mean Square Error is:  928488.5
# dst is:  1362.7094334450026
# check1
# check11 [5289  982] second is [1051 1127]
# check2
# The Mean Square Error is:  8990834.5
# dst is:  4240.479807757608
# check1
# check11 [5607  440] second is [1051 1127]
# check2
# The Mean Square Error is:  10614552.5
# dst is:  4607.505290284537
# from the logic 0.0
# [1178  451]
# row count is  56
# check1
# check11 [1941 1929] second is [1178  451]
# check2
# The Mean Square Error is:  1383326.5
# dst is:  1663.3258850868642
# check1
# check11 [3312   21] second is [1178  451]
# check2
# The Mean Square Error is:  2369428.0
# dst is:  2176.891361552064
# check1
# check11 [4553  161] second is [1178  451]
# check2
# The Mean Square Error is:  5737362.5
# dst is:  3387.4363462654173
# check1
# check11 [2027  176] second is [1178  451]
# check2
# The Mean Square Error is:  398213.0
# dst is:  892.4270278291665
# check1
# check11 [5289  982] second is [1178  451]
# check2
# The Mean Square Error is:  8591141.0
# dst is:  4145.151625694771
# check1
# check11 [5607  440] second is [1178  451]
# check2
# The Mean Square Error is:  9808081.0
# dst is:  4429.013659947325
# from the logic 0.0
# [2318 2085]
# row count is  57
# check1
# check11 [1941 1929] second is [2318 2085]
# check2
# The Mean Square Error is:  83232.5
# dst is:  408.0012254883556
# check1
# check11 [3312   21] second is [2318 2085]
# check2
# The Mean Square Error is:  2624066.0
# dst is:  2290.880180192757
# check1
# check11 [4553  161] second is [2318 2085]
# check2
# The Mean Square Error is:  4348500.5
# dst is:  2949.067818820042
# check1
# check11 [2027  176] second is [2318 2085]
# check2
# The Mean Square Error is:  1864481.0
# dst is:  1931.0520448708783
# check1
# check11 [5289  982] second is [2318 2085]
# check2
# The Mean Square Error is:  5021725.0
# dst is:  3169.140261963803
# check1
# check11 [5607  440] second is [2318 2085]
# check2
# The Mean Square Error is:  6761773.0
# dst is:  3677.437422989003
# from the logic 0.0
# [ 352 1230]
# row count is  58
# check1
# check11 [1941 1929] second is [ 352 1230]
# check2
# The Mean Square Error is:  1506761.0
# dst is:  1735.9498840692377
# check1
# check11 [3312   21] second is [ 352 1230]
# check2
# The Mean Square Error is:  5111640.5
# dst is:  3197.386589075522
# check1
# check11 [4553  161] second is [ 352 1230]
# check2
# The Mean Square Error is:  9395581.0
# dst is:  4334.877391576375
# check1
# check11 [2027  176] second is [ 352 1230]
# check2
# The Mean Square Error is:  1958270.5
# dst is:  1979.0252651242226
# check1
# check11 [5289  982] second is [ 352 1230]
# check2
# The Mean Square Error is:  12217736.5
# dst is:  4943.224959477366
# check1
# check11 [5607  440] second is [ 352 1230]
# check2
# The Mean Square Error is:  14119562.5
# dst is:  5314.049773948302
# from the logic 0.0
# [5703 1179]
# row count is  59
# check1
# check11 [1941 1929] second is [5703 1179]
# check2
# The Mean Square Error is:  7357572.0
# dst is:  3836.0323252026956
# check1
# check11 [3312   21] second is [5703 1179]
# check2
# The Mean Square Error is:  3528922.5
# dst is:  2656.660497692545
# check1
# check11 [4553  161] second is [5703 1179]
# check2
# The Mean Square Error is:  1179412.0
# dst is:  1535.846346481314
# check1
# check11 [2027  176] second is [5703 1179]
# check2
# The Mean Square Error is:  7259492.5
# dst is:  3810.378590114111
# check1
# check11 [5289  982] second is [5703 1179]
# check2
# The Mean Square Error is:  105102.5
# dst is:  458.48118827275783
# check1
# check11 [5607  440] second is [5703 1179]
# check2
# The Mean Square Error is:  277668.5
# dst is:  745.2093665541248
# from the logic 0.0
# [2868 1375]
# row count is  60
# check1
# check11 [1941 1929] second is [2868 1375]
# check2
# The Mean Square Error is:  583122.5
# dst is:  1079.9282383566049
# check1
# check11 [3312   21] second is [2868 1375]
# check2
# The Mean Square Error is:  1015226.0
# dst is:  1424.9392969526807
# check1
# check11 [4553  161] second is [2868 1375]
# check2
# The Mean Square Error is:  2156510.5
# dst is:  2076.7814039999494
# check1
# check11 [2027  176] second is [2868 1375]
# check2
# The Mean Square Error is:  1072441.0
# dst is:  1464.541566497858
# check1
# check11 [5289  982] second is [2868 1375]
# check2
# The Mean Square Error is:  3007845.0
# dst is:  2452.690359584756
# check1
# check11 [5607  440] second is [2868 1375]
# check2
# The Mean Square Error is:  4188173.0
# dst is:  2894.191769734687
# from the logic 0.0
# [5153 1097]
# row count is  61
# check1
# check11 [1941 1929] second is [5153 1097]
# check2
# The Mean Square Error is:  5504584.0
# dst is:  3318.0066304936763
# check1
# check11 [3312   21] second is [5153 1097]
# check2
# The Mean Square Error is:  2273528.5
# dst is:  2132.382939342744
# check1
# check11 [4553  161] second is [5153 1097]
# check2
# The Mean Square Error is:  618048.0
# dst is:  1111.798542902445
# check1
# check11 [2027  176] second is [5153 1097]
# check2
# The Mean Square Error is:  5310058.5
# dst is:  3258.852098515672
# check1
# check11 [5289  982] second is [5153 1097]
# check2
# The Mean Square Error is:  15860.5
# dst is:  178.10390225932727
# check1
# check11 [5607  440] second is [5153 1097]
# check2
# The Mean Square Error is:  318882.5
# dst is:  798.6019033285609
# from the logic 0.0
# [4510 2523]
# row count is  62
# check1
# check11 [1941 1929] second is [4510 2523]
# check2
# The Mean Square Error is:  3476298.5
# dst is:  2636.7777684135613
# check1
# check11 [3312   21] second is [4510 2523]
# check2
# The Mean Square Error is:  3847604.0
# dst is:  2774.023792255575
# check1
# check11 [4553  161] second is [4510 2523]
# check2
# The Mean Square Error is:  2790446.5
# dst is:  2362.3913731640655
# check1
# check11 [2027  176] second is [4510 2523]
# check2
# The Mean Square Error is:  5836849.0
# dst is:  3416.6793820901603
# check1
# check11 [5289  982] second is [4510 2523]
# check2
# The Mean Square Error is:  1490761.0
# dst is:  1726.7084293533753
# check1
# check11 [5607  440] second is [4510 2523]
# check2
# The Mean Square Error is:  2771149.0
# dst is:  2354.2085718984204
# from the logic 0.0
# [ 135 2707]
# row count is  63
# check1
# check11 [1941 1929] second is [ 135 2707]
# check2
# The Mean Square Error is:  1933460.0
# dst is:  1966.4485754781385
# check1
# check11 [3312   21] second is [ 135 2707]
# check2
# The Mean Square Error is:  8653962.5
# dst is:  4160.279437730115
# check1
# check11 [4553  161] second is [ 135 2707]
# check2
# The Mean Square Error is:  13000420.0
# dst is:  5099.101881704268
# check1
# ...
# check1
# check11 [3312   21] second is [1259 3173]
# check2
# The Mean Square Error is:  7074956.5
# dst is:  3761.637010664373
# check1
# check11 [4553  161] second is [1259 3173]
# check2
# The Mean Square Error is:  9961290.0
# dst is:  4463.4717429373295
# check1
# check11 [2027  176] second is [1259 3173]
# check2
# The Mean Square Error is:  4785916.5
# dst is:  3093.8379078419734
# check1
# check11 [5289  982] second is [1259 3173]
# check2
# The Mean Square Error is:  10520690.5
# dst is:  4587.088510155434
# check1
# check11 [5607  440] second is [1259 3173]
# check2
# The Mean Square Error is:  13187196.5
# dst is:  5135.600549108157
# from the logic 0.0
# [4488 1389]
# row count is  2100
# check1
# check11 [1941 1929] second is [4488 1389]
# check2
# The Mean Square Error is:  3389404.5
# dst is:  2603.6146028166304
# check1
# check11 [3312   21] second is [4488 1389]
# check2
# The Mean Square Error is:  1627200.0
# dst is:  1803.995565404749
# check1
# check11 [4553  161] second is [4488 1389]
# check2
# The Mean Square Error is:  756104.5
# dst is:  1229.7190736099037
# check1
# check11 [2027  176] second is [4488 1389]
# check2
# The Mean Square Error is:  3763945.0
# dst is:  2743.7000564930563
# check1
# check11 [5289  982] second is [4488 1389]
# check2
# The Mean Square Error is:  403625.0
# dst is:  898.4709232913439
# check1
# check11 [5607  440] second is [4488 1389]
# check2
# The Mean Square Error is:  1076381.0
# dst is:  1467.2293617563682
# from the logic 0.0
# [2181  597]
# row count is  2101
# check1
# check11 [1941 1929] second is [2181  597]
# check2
# The Mean Square Error is:  915912.0
# dst is:  1353.4489277397947
# check1
# check11 [3312   21] second is [2181  597]
# check2
# The Mean Square Error is:  805468.5
# dst is:  1269.2269300641237
# check1
# check11 [4553  161] second is [2181  597]
# check2
# The Mean Square Error is:  2908240.0
# dst is:  2411.737962549
# check1
# check11 [2027  176] second is [2181  597]
# check2
# The Mean Square Error is:  100478.5
# dst is:  448.2822771424273
# check1
# check11 [5289  982] second is [2181  597]
# check2
# The Mean Square Error is:  4903944.5
# dst is:  3131.7549393271497
# check1
# check11 [5607  440] second is [2181  597]
# check2
# The Mean Square Error is:  5881062.5
# dst is:  3429.5954571931657
# from the logic 0.0
# [3163  830]
# row count is  2102
# check1
# check11 [1941 1929] second is [3163  830]
# check2
# The Mean Square Error is:  1350542.5
# dst is:  1643.4977943398646
# check1
# check11 [3312   21] second is [3163  830]
# check2
# The Mean Square Error is:  338341.0
# dst is:  822.606831967739
# check1
# check11 [4553  161] second is [3163  830]
# check2
# The Mean Square Error is:  1189830.5
# dst is:  1542.614987610324
# check1
# check11 [2027  176] second is [3163  830]
# check2
# The Mean Square Error is:  859106.0
# dst is:  1310.8058590042997
# check1
# check11 [5289  982] second is [3163  830]
# check2
# The Mean Square Error is:  2271490.0
# dst is:  2131.426752201445
# check1
# check11 [5607  440] second is [3163  830]
# check2
# The Mean Square Error is:  3062618.0
# dst is:  2474.921412893751
# from the logic 0.0
# [1930 1584]
# row count is  2103
# check1
# check11 [1941 1929] second is [1930 1584]
# check2
# The Mean Square Error is:  59573.0
# dst is:  345.1753177734468
# check1
# check11 [3312   21] second is [1930 1584]
# check2
# The Mean Square Error is:  2176446.5
# dst is:  2086.358789853749
# check1
# check11 [4553  161] second is [1930 1584]
# check2
# The Mean Square Error is:  4452529.0
# dst is:  2984.1343803521986
# check1
# check11 [2027  176] second is [1930 1584]
# check2
# The Mean Square Error is:  995936.5
# dst is:  1411.3373090795835
# check1
# check11 [5289  982] second is [1930 1584]
# check2
# The Mean Square Error is:  5822642.5
# dst is:  3412.518864416723
# check1
# check11 [5607  440] second is [1930 1584]
# check2
# The Mean Square Error is:  7414532.5
# dst is:  3850.8525030180003
# from the logic 0.0
# [3821 2337]
# row count is  2104
# check1
# check11 [1941 1929] second is [3821 2337]
# check2
# The Mean Square Error is:  1850432.0
# dst is:  1923.7629791634936
# check1
# check11 [3312   21] second is [3821 2337]
# check2
# The Mean Square Error is:  2811468.5
# dst is:  2371.2732866542397
# check1
# check11 [4553  161] second is [3821 2337]
# check2
# The Mean Square Error is:  2635400.0
# dst is:  2295.8222927744214
# check1
# check11 [2027  176] second is [3821 2337]
# check2
# The Mean Square Error is:  3944178.5
# dst is:  2808.6219040661204
# check1
# check11 [5289  982] second is [3821 2337]
# check2
# The Mean Square Error is:  1995524.5
# dst is:  1997.7609967160736
# check1
# check11 [5607  440] second is [3821 2337]
# check2
# The Mean Square Error is:  3394202.5
# dst is:  2605.456773773075
# from the logic 0.0
# [5710  337]
# row count is  2105
# check1
# check11 [1941 1929] second is [5710  337]
# check2
# The Mean Square Error is:  8369912.5
# dst is:  4091.4331230022567
# check1
# check11 [3312   21] second is [5710  337]
# check2
# The Mean Square Error is:  2925130.0
# dst is:  2418.7310722773627
# check1
# check11 [4553  161] second is [5710  337]
# check2
# The Mean Square Error is:  684812.5
# dst is:  1170.309788047592
# check1
# check11 [2027  176] second is [5710  337]
# check2
# The Mean Square Error is:  6795205.0
# dst is:  3686.517326691955
# check1
# check11 [5289  982] second is [5710  337]
# check2
# The Mean Square Error is:  296633.0
# dst is:  770.2376256714547
# check1
# check11 [5607  440] second is [5710  337]
# check2
# The Mean Square Error is:  10609.0
# dst is:  145.6639969244288
# from the logic 0.0
# [5128 1212]
# row count is  2106
# check1
# check11 [1941 1929] second is [5128 1212]
# check2
# The Mean Square Error is:  5335529.0
# dst is:  3266.658537404851
# check1
# check11 [3312   21] second is [5128 1212]
# check2
# The Mean Square Error is:  2358168.5
# dst is:  2171.71291841256
# check1
# check11 [4553  161] second is [5128 1212]
# check2
# The Mean Square Error is:  717613.0
# dst is:  1198.0091819347629
# check1
# check11 [2027  176] second is [5128 1212]
# check2
# The Mean Square Error is:  5344748.5
# dst is:  3269.479622202897
# check1
# check11 [5289  982] second is [5128 1212]
# check2
# The Mean Square Error is:  39410.5
# dst is:  280.7507791618752
# check1
# check11 [5607  440] second is [5128 1212]
# check2
# The Mean Square Error is:  412712.5
# dst is:  908.5290309065529
# from the logic 0.0
# [2326 3298]
# row count is  2107
# check1
# check11 [1941 1929] second is [2326 3298]
# check2
# The Mean Square Error is:  1011193.0
# dst is:  1422.1061845024092
# check1
# check11 [3312   21] second is [2326 3298]
# check2
# The Mean Square Error is:  5855462.5
# dst is:  3422.1228791497247
# check1
# check11 [4553  161] second is [2326 3298]
# check2
# The Mean Square Error is:  7400149.0
# dst is:  3847.1155428450547
# check1
# check11 [2027  176] second is [2326 3298]
# check2
# The Mean Square Error is:  4918142.5
# dst is:  3136.2852229986993
# check1
# check11 [5289  982] second is [2326 3298]
# check2
# The Mean Square Error is:  7071612.5
# dst is:  3760.747930930761
# check1
# check11 [5607  440] second is [2326 3298]
# check2
# The Mean Square Error is:  9466562.5
# dst is:  4351.2210929806815
# from the logic 0.0
# [3394 2959]
# row count is  2108
# check1
# check11 [1941 1929] second is [3394 2959]
# check2
# The Mean Square Error is:  1586054.5
# dst is:  1781.041549206531
# check1
# check11 [3312   21] second is [3394 2959]
# check2
# The Mean Square Error is:  4319284.0
# dst is:  2939.144093099214
# check1
# check11 [4553  161] second is [3394 2959]
# check2
# The Mean Square Error is:  4586042.5
# dst is:  3028.5450302084005
# check1
# check11 [2027  176] second is [3394 2959]
# check2
# The Mean Square Error is:  4806889.0
# dst is:  3100.609294961234
# check1
# check11 [5289  982] second is [3394 2959]
# check2
# The Mean Square Error is:  3749777.0
# dst is:  2738.531358228348
# check1
# check11 [5607  440] second is [3394 2959]
# check2
# The Mean Square Error is:  5621365.0
# dst is:  3353.018043494547
# from the logic 0.0
# [3118 2001]
# row count is  2109
# check1
# check11 [1941 1929] second is [3118 2001]
# check2
# The Mean Square Error is:  695256.5
# dst is:  1179.2001526458516
# check1
# check11 [3312   21] second is [3118 2001]
# check2
# The Mean Square Error is:  1979018.0
# dst is:  1989.4813394450323
# check1
# check11 [4553  161] second is [3118 2001]
# check2
# The Mean Square Error is:  2722412.5
# dst is:  2333.4148795274277
# check1
# check11 [2027  176] second is [3118 2001]
# check2
# The Mean Square Error is:  2260453.0
# dst is:  2126.242225147455
# check1
# check11 [5289  982] second is [3118 2001]
# check2
# The Mean Square Error is:  2875801.0
# dst is:  2398.2497784843013
# check1
# check11 [5607  440] second is [3118 2001]
# check2
# The Mean Square Error is:  4315921.0
# dst is:  2937.999659632383
# from the logic 0.0
# [4489  858]
# row count is  2110
# check1
# check11 [1941 1929] second is [4489  858]
# check2
# The Mean Square Error is:  3819672.5
# dst is:  2763.9365043358
# check1
# check11 [3312   21] second is [4489  858]
# check2
# The Mean Square Error is:  1042949.0
# dst is:  1444.2638263142921
# check1
# check11 [4553  161] second is [4489  858]
# check2
# The Mean Square Error is:  244952.5
# dst is:  699.9321395678298
# check1
# check11 [2027  176] second is [4489  858]
# check2
# The Mean Square Error is:  3263284.0
# dst is:  2554.7148568871635
# check1
# check11 [5289  982] second is [4489  858]
# check2
# The Mean Square Error is:  327688.0
# dst is:  809.5529630604782
# check1
# check11 [5607  440] second is [4489  858]
# check2
# The Mean Square Error is:  712324.0
# dst is:  1193.5861929496336
# from the logic 0.0
# [3414  998]
# row count is  2111
# check1
# check11 [1941 1929] second is [3414  998]
# check2
# The Mean Square Error is:  1518245.0
# dst is:  1742.5527251707479
# check1
# check11 [3312   21] second is [3414  998]
# check2
# The Mean Square Error is:  482466.5
# dst is:  982.3100325253733
# check1
# check11 [4553  161] second is [3414  998]
# check2
# The Mean Square Error is:  998945.0
# dst is:  1413.4673678582042
# check1
# check11 [2027  176] second is [3414  998]
# check2
# The Mean Square Error is:  1299726.5
# dst is:  1612.2819232379925
# check1
# check11 [5289  982] second is [3414  998]
# check2
# The Mean Square Error is:  1757940.5
# dst is:  1875.0682654239552
# check1
# check11 [5607  440] second is [3414  998]
# check2
# The Mean Square Error is:  2560306.5
# dst is:  2262.877150885571
# from the logic 0.0
# [ 984 3366]
# row count is  2112
# check1
# check11 [1941 1929] second is [ 984 3366]
# check2
# The Mean Square Error is:  1490409.0
# dst is:  1726.5045612450608
# check1
# check11 [3312   21] second is [ 984 3366]
# check2
# The Mean Square Error is:  8304304.5
# dst is:  4075.366118522359
# check1
# check11 [4553  161] second is [ 984 3366]
# check2
# The Mean Square Error is:  11504893.0
# dst is:  4796.851675839061
# check1
# check11 [2027  176] second is [ 984 3366]
# check2
# The Mean Square Error is:  5631974.5
# dst is:  3356.1807162308764
# check1
# check11 [5289  982] second is [ 984 3366]
# check2
# The Mean Square Error is:  12108240.5
# dst is:  4921.024385227124
# check1
# check11 [5607  440] second is [ 984 3366]
# check2
# The Mean Square Error is:  14966802.5
# dst is:  5471.1612112969215
# from the logic 0.0
# [1595 1035]
# row count is  2113
# check1
# check11 [1941 1929] second is [1595 1035]
# check2
# The Mean Square Error is:  459476.0
# dst is:  958.6198412300885
# check1
# check11 [3312   21] second is [1595 1035]
# check2
# The Mean Square Error is:  1988142.5
# dst is:  1994.0624363344293
# check1
# check11 [4553  161] second is [1595 1035]
# check2
# The Mean Square Error is:  4756820.0
# dst is:  3084.4189079954754
# check1
# check11 [2027  176] second is [1595 1035]
# check2
# The Mean Square Error is:  462252.5
# dst is:  961.5118304004377
# check1
# check11 [5289  982] second is [1595 1035]
# check2
# The Mean Square Error is:  6824222.5
# dst is:  3694.3801915882996
# check1
# check11 [5607  440] second is [1595 1035]
# check2
# The Mean Square Error is:  8225084.5
# dst is:  4055.880792133812
# from the logic 0.0
# [1671 1271]
# row count is  2114
# check1
# check11 [1941 1929] second is [1671 1271]
# check2
# The Mean Square Error is:  252932.0
# dst is:  711.2411686622197
# check1
# check11 [3312   21] second is [1671 1271]
# check2
# The Mean Square Error is:  2127690.5
# dst is:  2062.8574841709255
# check1
# check11 [4553  161] second is [1671 1271]
# check2
# The Mean Square Error is:  4769012.0
# dst is:  3088.369148919863
# check1
# check11 [2027  176] second is [1671 1271]
# check2
# The Mean Square Error is:  662880.5
# dst is:  1151.4169531494663
# check1
# check11 [5289  982] second is [1671 1271]
# check2
# The Mean Square Error is:  6586722.5
# dst is:  3629.5240734840154
# check1
# check11 [5607  440] second is [1671 1271]
# check2
# The Mean Square Error is:  8091328.5
# dst is:  4022.76733107944
# from the logic 0.0
# [3690 1616]
# row count is  2115
# check1
# check11 [1941 1929] second is [3690 1616]
# check2
# The Mean Square Error is:  1578485.0
# dst is:  1776.786424981911
# check1
# check11 [3312   21] second is [3690 1616]
# check2
# The Mean Square Error is:  1343454.5
# dst is:  1639.179367854537
# check1
# check11 [4553  161] second is [3690 1616]
# check2
# The Mean Square Error is:  1430897.0
# dst is:  1691.68377659656
# check1
# check11 [2027  176] second is [3690 1616]
# check2
# The Mean Square Error is:  2419584.5
# dst is:  2199.811128256242
# check1
# check11 [5289  982] second is [3690 1616]
# check2
# The Mean Square Error is:  1479378.5
# dst is:  1720.1037759391147
# check1
# check11 [5607  440] second is [3690 1616]
# check2
# The Mean Square Error is:  2528932.5
# dst is:  2248.969764136459
# from the logic 0.0
# [5113  920]
# row count is  2116
# check1
# check11 [1941 1929] second is [5113  920]
# check2
# The Mean Square Error is:  5539832.5
# dst is:  3328.6130745402056
# check1
# check11 [3312   21] second is [5113  920]
# check2
# The Mean Square Error is:  2025901.0
# dst is:  2012.9088404594977
# check1
# check11 [4553  161] second is [5113  920]
# check2
# The Mean Square Error is:  444840.5
# dst is:  943.2290283913022
# check1
# check11 [2027  176] second is [5113  920]
# check2
# The Mean Square Error is:  5038466.0
# dst is:  3174.4183719226426
# check1
# check11 [5289  982] second is [5113  920]
# check2
# The Mean Square Error is:  17410.0
# dst is:  186.60117898877274
# check1
# check11 [5607  440] second is [5113  920]
# check2
# The Mean Square Error is:  237218.0
# dst is:  688.7931474688173
# from the logic 0.0
# [5441 2081]
# row count is  2117
# check1
# check11 [1941 1929] second is [5441 2081]
# check2
# The Mean Square Error is:  6136552.0
# dst is:  3503.299016641314
# check1
# check11 [3312   21] second is [5441 2081]
# check2
# The Mean Square Error is:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-bccaed8d79af> in <module>
#      34                 summation = summation + squared_difference  #taking a sum of all the differences
#      35             MSE = summation/n  #dividing summation by total values to obtain average
# ---> 36             print("The Mean Square Error is: " , MSE)
#      37             dst = distance.euclidean(y, y_bar)
#      38             print("dst is: " , dst)
#
# ~\.conda\envs\gpu38\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\.conda\envs\gpu38\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\.conda\envs\gpu38\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     489                                  copy_threshold=self.copy_threshold)
#     490             data.group = group
# --> 491         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     492
#     493     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\.conda\envs\gpu38\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
import numpy as np
from scipy.spatial import distance
import pandas as pd
import pickle
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
listofcol='age,gender,height,weight,ap_hi,ap_lo,cholesterol,gluc,smoke,alco,active'.split(',')
#listofcolumns=['age,gender,height,weight,ap_hi,ap_lo,cholesterol,gluc,smoke,alco,active,cardio']


import pandas as pd
import pickle
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

def proposedlogic(finaldff):
    threshold=0.50
    df1=pd.read_csv('ratings.csv',sep=',',error_bad_lines=False)

    print(len(df1))
    print(df1)
    df=df1#.sample(n=1000,replace=True)
    X = df.iloc[:,:-1].values # We drop our "target" feature and use all the remaining features in our dataframe to train the model.
    y = df.iloc[:,11].values

    X = df[['gender','cholesterol','smoke','alco','active']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
    Y = df['cardio']
    X1 = X.iloc[:,:].values # We drop our "target" feature and use all the remaining features in our dataframe to train the model.
    X2=finaldff.iloc[:,:].values
    outexpect=[]
    overall=[]
    for row in X2:
        countis=0
        for row1 in X1:
            print(row1)
            y=row
            summation = 0
            print('check1')
            y_bar=row1
            print('check11',y_bar,'second is',y)
            #if y!=y_bar:
            print('check2')
            n = len(y) #finding total number of items in list
            for i in range (0,n):  #looping through each element of the list
                difference = y[i] - y_bar[i]  #finding the difference between observed and predicted value
                squared_difference = difference**2  #taking square of the differene 
                summation = summation + squared_difference  #taking a sum of all the differences
            MSE = summation/n  #dividing summation by total values to obtain average
            print("The Mean Square Error is: " , MSE)
            dst = distance.euclidean(y, y_bar)
            print("dst is: " , dst)
            if dst<0.02:
                outexpect.append(1.0)
            else:
                outexpect.append(0.0)
            if MSE<=0.5:
                outexpect.append(1.0)
            else:
                outexpect.append(0.0)
            #outexpect+=1
            #if len(outexpect)>len(X1):
            if len(outexpect)>10:
                break
    #outexpect.append(valis)
    #y_actu.append(expected)
    valmax=max(outexpect,key=outexpect.count)
    #outexpect
    overall.append(valmax)
    print('from the logic',valmax)
    return valmax
    #print(val,valis)
    

proposedlogic(finaldff)
